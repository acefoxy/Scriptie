# %%
import pandas as pd

df = pd.read_csv('TK2017_revised.csv', sep=';' ,encoding= 'latin1')
df = df[['gemeente','Partij']]
df2 = pd.read_csv('2017_all.csv',sep=',')
df2 = df2.rename(columns={"Regio's": "gemeente"})


df3 = pd.merge(df,df2, on='gemeente')

#df3 = df3[df3.columns[pd.Series(df3.columns).str.startswith('Bevolking')]]



df4= pd.DataFrame(df3.pivot_table(index='Partij')).dropna()



NUMBER = list(df3.columns[3:])



y = df3['Partij'].values
X = df3[NUMBER].fillna(-1000).values

# %%
from sklearn.ensemble import ExtraTreesClassifier

from sklearn.feature_selection import SelectFromModel


print(X.shape)

clf = ExtraTreesClassifier()
lf = clf.fit(X, y)
print(clf.feature_importances_)

model = SelectFromModel(clf, prefit=True)
X = model.transform(X)
   
print(X.shape)
# Out:
# (1656, 271)
# [5.81341172e-04 4.01974069e-03 3.17720176e-03 4.34554226e-03
#  1.81308947e-03 3.15783360e-03 4.43179220e-03 4.52091402e-03
#  2.11856686e-03 1.08456342e-03 3.12482170e-03 2.50516629e-03
#  3.07772700e-03 8.62541964e-03 6.48049490e-03 3.05638666e-03
#  8.27371473e-03 5.27654658e-03 1.74705822e-03 6.30472150e-03
#  3.43775917e-03 6.13446425e-03 6.33273727e-03 8.23216085e-03
#  2.25094675e-03 1.21181011e-03 1.56618706e-03 2.12545800e-03
#  1.86905634e-03 3.63217916e-03 6.71786272e-03 5.08400136e-03
#  3.92936443e-03 7.23498837e-03 4.58908162e-03 4.12827345e-03
#  7.93877515e-03 9.72443667e-03 5.81158889e-03 8.56482892e-03
#  5.84440285e-03 3.45066838e-03 2.86189559e-03 6.23266108e-03
#  9.79839161e-03 1.44832105e-02 9.66375888e-03 8.47612107e-03
#  6.40248058e-03 1.05209283e-02 4.59702704e-03 4.91205968e-03
#  1.86317423e-03 2.37802518e-03 1.71124375e-03 5.61316582e-03
#  1.48277023e-02 4.72679429e-03 1.89505628e-03 3.13748541e-03
#  2.70216690e-03 3.71528211e-03 3.93290353e-03 3.35494259e-03
#  1.59760306e-03 3.91207638e-03 1.28805136e-03 4.32602630e-03
#  8.16189029e-04 5.86448806e-03 2.35342210e-03 1.80685370e-03
#  1.92511276e-03 1.88206610e-03 2.10532706e-03 1.85078057e-03
#  2.04033248e-03 1.16035205e-03 4.64295565e-03 7.21191436e-04
#  2.62188431e-03 3.11202776e-03 3.67495715e-03 2.36360910e-03
#  4.34532474e-03 2.86172145e-03 1.21411190e-02 3.54852455e-03
#  7.72889587e-03 1.19236625e-02 2.56809803e-03 2.45150201e-04
#  7.02314421e-04 4.08432477e-03 5.50150022e-03 4.84460935e-03
#  1.17298751e-03 2.56814659e-03 5.85875415e-04 1.17833135e-02
#  3.27654655e-03 1.63728740e-03 5.36470293e-03 3.39541637e-03
#  3.16724844e-03 2.83100613e-03 1.68478110e-03 4.49952163e-03
#  1.64855995e-03 9.15277769e-04 1.67006667e-03 4.06597802e-03
#  6.37982364e-04 2.30379020e-03 1.00176277e-03 9.23792079e-04
#  6.84386112e-04 1.57440043e-03 1.17213437e-03 8.79776363e-04
ascending=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in create_block_manager_from_blocks(blocks, axes)
#    4621                 blocks = [make_block(values=blocks[0],
# -> 4622                                      placement=slice(0, len(axes[0])))]
#    4623
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in make_block(values, placement, klass, ndim, dtype, fastpath)
#    2956
# -> 2957     return klass(values, ndim=ndim, fastpath=fastpath, placement=placement)
#    2958
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in __init__(self, values, placement, ndim, fastpath)
#     119                              'implies %d' % (len(self.values),
# --> 120                                              len(self.mgr_locs)))
#     121
#
# ValueError: Wrong number of items passed 271, placement implies 252
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-4eddc319551d> in <module>()
#      15
#      16 # Dump components relations with features:
# ---> 17 z = pd.DataFrame(pca.components_,columns=data_scaled.columns,index=['CDA','PVDA','PVV','SGP','SP','VVD'])
#      18
#      19
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     359             else:
#     360                 mgr = self._init_ndarray(data, index, columns, dtype=dtype,
# --> 361                                          copy=copy)
#     362         elif isinstance(data, (list, types.GeneratorType)):
#     363             if isinstance(data, types.GeneratorType):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _init_ndarray(self, values, index, columns, dtype, copy)
#     531             values = maybe_infer_to_datetimelike(values)
#     532
# --> 533         return create_block_manager_from_blocks([values], [columns, index])
#     534
#     535     @property
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in create_block_manager_from_blocks(blocks, axes)
#    4629         blocks = [getattr(b, 'values', b) for b in blocks]
#    4630         tot_items = sum(b.shape[0] for b in blocks)
# -> 4631         construction_error(tot_items, blocks[0].shape[1:], axes, e)
#    4632
#    4633
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in construction_error(tot_items, block_shape, axes, e)
#    4606         raise ValueError("Empty data passed with indices specified.")
#    4607     raise ValueError("Shape of passed values is {0}, indices imply {1}".format(
# -> 4608         passed, implied))
#    4609
#    4610
#
# ValueError: Shape of passed values is (271, 6), indices imply (252, 6)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Build a forest and compute the feature importances
forest = ExtraTreesClassifier(n_estimators=250,
                              random_state=0)

forest.fit(X, y)
importances = forest.feature_importances_
std = np.std([tree.feature_importances_ for tree in forest.estimators_],
             axis=0)
indices = np.argsort(importances)[::-1]

# Print the feature ranking
print("Feature ranking:")

for f in range(X.shape[1]):
    print("%d. feature %d (%f)" % (f + 1, indices[f], importances[indices[f]]))

# Plot the feature importances of the forest
plt.figure()
plt.title("Feature importances")
plt.bar(range(X.shape[1]), importances[indices],
       color="r", yerr=std[indices], align="center")
plt.xticks(range(X.shape[1]), indices)
plt.xlim([-1, X.shape[1]])
plt.show()


NUMBER[45],NUMBER[68]
# Out:
# Feature ranking:
# 1. feature 34 (0.036128)
# 2. feature 17 (0.035958)
# 3. feature 14 (0.032769)
# 4. feature 42 (0.027620)
# 5. feature 32 (0.027194)
# 6. feature 30 (0.025897)
# 7. feature 36 (0.025534)
# 8. feature 27 (0.025425)
# 9. feature 33 (0.025111)
# 10. feature 50 (0.025049)
# 11. feature 29 (0.024779)
# 12. feature 43 (0.024772)
# 13. feature 38 (0.024770)
# 14. feature 9 (0.023896)
# 15. feature 10 (0.023892)
# 16. feature 25 (0.023565)
# 17. feature 24 (0.023453)
# 18. feature 37 (0.021698)
# 19. feature 13 (0.020751)
# 20. feature 39 (0.020315)
# 21. feature 26 (0.019725)
# 22. feature 31 (0.019208)
# 23. feature 49 (0.018147)
# 24. feature 40 (0.017804)
# 25. feature 48 (0.017518)
# 26. feature 19 (0.017485)
# 27. feature 3 (0.017400)
# 28. feature 0 (0.017271)
# 29. feature 20 (0.017021)
# 30. feature 23 (0.016911)
# 31. feature 22 (0.016238)
# 32. feature 1 (0.016233)
# 33. feature 18 (0.015879)
# 34. feature 2 (0.015740)
# 35. feature 47 (0.015670)
# 36. feature 16 (0.015614)
# 37. feature 21 (0.015465)
# 38. feature 45 (0.015407)
# 39. feature 35 (0.015137)
# 40. feature 6 (0.014989)
# 41. feature 7 (0.014869)
# 42. feature 46 (0.014581)
# 43. feature 11 (0.014509)
# 44. feature 44 (0.014342)
# 45. feature 28 (0.013752)
# 46. feature 5 (0.013703)
# 47. feature 41 (0.013263)
# 48. feature 4 (0.013243)
# 49. feature 12 (0.012856)
# 50. feature 8 (0.012108)
# 51. feature 15 (0.009335)
# ('Bevolking/Bevolkingssamenstelling op 1 januari/Migratieachtergrond/Migratieachtergrond. relatief/Met migratieachtergrond/Niet-westerse migratieachtergrond/Totaal niet-westerse migratieachtergrond (%)',
#  'Bevolking/Bevolkingsontwikkeling/Verhuizingen/Vestiging uit andere gemeente (aantal)')

# %%
#features


from sklearn.ensemble import RandomForestClassifier

rnd_clf = RandomForestClassifier(n_estimators=500, n_jobs=1, random_state=42)
rnd_clf.fit(X, y)




a = {name: importance for name, importance in zip(NUMBER, rnd_clf.feature_importances_)}
  
df = pd.DataFrame(list(a.items()), columns=['name', 'importance'])

df2 = df.sort_values('importance',ascending=False)


df2.name

# %%
# Out:
# 19    Bevolking/Bevolkingssamenstelling op 1 januari...
# 23    Bevolking/Bevolkingssamenstelling op 1 januari...
# 5     Bevolking/Bevolkingssamenstelling op 1 januari...
# 32    Bevolking/Bevolkingssamenstelling op 1 januari...
# 33    Bevolking/Bevolkingssamenstelling op 1 januari...
# 7     Bevolking/Bevolkingssamenstelling op 1 januari...
# 17    Bevolking/Bevolkingssamenstelling op 1 januari...
# 28    Bevolking/Bevolkingssamenstelling op 1 januari...
# 27    Bevolking/Bevolkingssamenstelling op 1 januari...
# 3     Bevolking/Bevolkingssamenstelling op 1 januari...
# 18    Bevolking/Bevolkingssamenstelling op 1 januari...
# 22    Bevolking/Bevolkingssamenstelling op 1 januari...
# 8     Bevolking/Bevolkingssamenstelling op 1 januari...
# 4     Bevolking/Bevolkingssamenstelling op 1 januari...
# 14    Bevolking/Bevolkingssamenstelling op 1 januari...
# 31    Bevolking/Bevolkingssamenstelling op 1 januari...
# 20    Bevolking/Bevolkingssamenstelling op 1 januari...
# 1     Bevolking/Bevolkingssamenstelling op 1 januari...
# 15    Bevolking/Bevolkingssamenstelling op 1 januari...
# 25    Bevolking/Bevolkingssamenstelling op 1 januari...
# 0     Bevolking/Bevolkingssamenstelling op 1 januari...
# 12    Bevolking/Bevolkingssamenstelling op 1 januari...
# 11    Bevolking/Bevolkingssamenstelling op 1 januari...
# 21    Bevolking/Bevolkingssamenstelling op 1 januari...
# 9     Bevolking/Bevolkingssamenstelling op 1 januari...
# 13    Bevolking/Bevolkingssamenstelling op 1 januari...
# 2     Bevolking/Bevolkingssamenstelling op 1 januari...
# 10    Bevolking/Bevolkingssamenstelling op 1 januari...
# 26    Bevolking/Bevolkingssamenstelling op 1 januari...
# 6     Bevolking/Bevolkingssamenstelling op 1 januari...
# 30    Bevolking/Bevolkingssamenstelling op 1 januari...
# 24    Bevolking/Bevolkingssamenstelling op 1 januari...
# 29    Bevolking/Bevolkingssamenstelling op 1 januari...
# 16    Bevolking/Bevolkingssamenstelling op 1 januari...
# Name: name, dtype: object

# %%
import matplotlib.pyplot as plt

# %matplotlib inline

features = NUMBER
importances = rnd_clf.feature_importances_
indices = np.argsort(importances)
