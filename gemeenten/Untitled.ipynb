# %%
import pandas as pd

# %%
csv = pd.read_csv('bevolkingbouwenwonen.csv', sep ='\t')
csv2 = pd.read_csv('onderwijsarbeidinkomenvoorgaandjaarsocialezekerheidbedrijfsvestigingenlandbouw.csv', sep ='\t')
csv3 = pd.read_csv('final.csv', sep ='\t')

# %%
df = pd.merge(csv,csv2)
df = pd.merge(df,csv3)

df.to_csv('2010_all.csv')

# %%
a = pd.read_csv('TK2017_revised.csv', sep= ',')
a.head(20)
# Out:
#     Unnamed: 0             gemeente    VVD   CDA   PVV    D66     SP     GL  \
# 0            0           Appingedam    889  1033  1095    605   1431    559
# 1            1                Bedum    854  1446   503    682    885    664
# 2            2         Bellingwedde    821   555  1123    402   1069    411
# 3            3             De Marne    864  1105   828    457    902    574
# 4            4             Delfzijl   1975  2080  2401   1190   2540   1028
# 5            5             Eemsmond   1259  1731  1124    738   1667    763
# 6            6            Groningen  17696  8621  8723  25973  14152  24642
# 7            7           Grootegast   1063  2052   867    497    781    413
# 8            8                Haren   2946  1526   656   2301    854   1863
# 9            9  Hoogezand-Sappemeer   2832  1788  3050   1713   3753   1808
# 10          10                 Leek   2145  1969  1372   1234   1478   1090
# ...
